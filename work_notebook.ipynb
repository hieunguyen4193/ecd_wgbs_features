# %%
import pandas as pd 
import os

inputbed = "/media/hieunguyen/HNSD01/src/ecd_wgbs_features/hg19_CpG_clusters/CpG_clusters_whole_genome_radius_100_minCpG_5.bed"
df = pd.read_csv(inputbed, sep = "\t", header = None)
filename = inputbed.split("/")[-1]

for chr in range(1, 23):
    tmpdf = df[df[0] == chr].copy()
    tmpdf.to_csv(os.path.join(inputbed.replace(filename, ""), filename.replace(".bed", ""), f"chr{chr}.bed"))

# %%
tmpdf
# Out:
#          0         1         2              3  4                     5
# 719366  22  16085553  16085649     22_bin_139  7  22:16085553-16085649
# 719367  22  16085679  16085776     22_bin_140  5  22:16085679-16085776
# 719368  22  16092476  16092578     22_bin_170  5  22:16092476-16092578
# 719369  22  16095913  16095990     22_bin_180  5  22:16095913-16095990
# 719370  22  16096014  16096048     22_bin_181  5  22:16096014-16096048
# ...     ..       ...       ...            ... ..                   ...
# 752940  22  51237174  51237265  22_bin_189286  7  22:51237174-51237265
# 752941  22  51238794  51238889  22_bin_189294  5  22:51238794-51238889
# 752942  22  51243990  51244084  22_bin_189314  7  22:51243990-51244084
# 752943  22  51244107  51244205  22_bin_189315  7  22:51244107-51244205
# 752944  22  51244227  51244314  22_bin_189316  9  22:51244227-51244314
#
# [33579 rows x 6 columns]
