# %%
import pandas as pd 
import os

inputbed = "/media/hieunguyen/HNSD01/src/ecd_wgbs_features/hg19_CpG_clusters/CpG_clusters_whole_genome_radius_100_minCpG_5.bed"
df = pd.read_csv(inputbed, sep = "\t", header = None)
filename = inputbed.split("/")[-1]

for chr in range(1, 23):
    tmpdf = df[df[0] == chr].copy()
    tmpdf.to_csv(os.path.join(inputbed.replace(filename, ""), filename.replace(".bed", ""), f"chr{chr}.bed"))
# Out:
#          0          1          2             3   4                      5
# 0        1      10467      10563       1_bin_0   9          1:10467-10563
# 1        1      10569      10670       1_bin_1  19          1:10569-10670
# 2        1      10671      10766       1_bin_2  23          1:10671-10766
# 3        1      10774      10867       1_bin_3  20          1:10774-10867
# 4        1      10883      10984       1_bin_4  15          1:10883-10984
# ...     ..        ...        ...           ...  ..                    ...
# 1147497  9  141140159  141140231  9_bin_502905   6  9:141140159-141140231
# 1147498  9  141140601  141140688  9_bin_502908   5  9:141140601-141140688
# 1147499  9  141143431  141143525  9_bin_502921   8  9:141143431-141143525
# 1147500  9  141152968  141153051  9_bin_502956   5  9:141152968-141153051
# 1147501  9  141153258  141153358  9_bin_502958   6  9:141153258-141153358
#
# [1147502 rows x 6 columns]
